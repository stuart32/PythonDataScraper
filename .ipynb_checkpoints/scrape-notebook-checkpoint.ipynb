# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://espc.com/house-prices/edinburgh")
soup = BeautifulSoup(page.content, 'html.parser')

# %%
html = list(soup.children)[2]

# %%
list(html.children)[3]
# Out:
# <body>\n<div id="notificationPanel"></div>\n<a class="away skip-link" href="#content" tabindex="1">Skip to main content</a>\n<header role="banner">\n<div class="wrapper">\n<div class="clearfix">\n<a class="logo col small_1 large_1" href="/" tabindex="2">\n<img alt="ESPC" data-fallback="/resources/images/espc-logo.png" src="/resources/images/espc-logo.svg"/>\n</a>\n<nav role="navigation">\n<div class="nav-wrapper col small_3 large_2 small_switch large_switch no-bottom no-left clearfix">\n<ul class="nav-my-espc">\n<li class="nav-link prominent-link">\n<a class="button" href="/users/register" tabindex="11">Sign up</a>\n</li>\n<li class="nav-link account-link">\n<a class="button inverse" href="/users/login?rp=/users/properties" tabindex="10">Log in</a>\n</li>\n</ul>\n</div>\n<ul class="nav-primary col small_4 large_9 no-bottom no-right hide clearfix">\n<li><a href="/explore-areas" tabindex="3">Explore Areas</a></li>\n<li><a href="/useful-info" tabindex="4">Useful info</a></li>\n<li><a href="/lettings" tabindex="5">Lettings</a></li>\n<li><a href="/mortgages" tabindex="6">Mortgages</a></li>\n<li><a href="/news" tabindex="7">News</a></li>\n<li><a href="/find-an-agent" tabindex="8">Find an agent</a></li>\n<li class="nav-search"><a class="icon-search" href="/" tabindex="9"><span class="away">Search</span></a></li>\n</ul>\n</nav>\n</div>\n</div>\n</header>\n<main class="search-results search-results--past-sales" id="content" role="main">\n</main>\n<footer class="clearfix" id="footer" role="contentinfo">\n<div class="wrapper">\n<div class="clearfix">\n<ul class="col full_width clearfix">\n<li><a href="/">Home</a></li>\n<li><a href="/new">New Properties</a></li>\n<li><a href="/property-for-rent/scotland">Properties for Rent</a></li>\n<li><a href="/contact-us">Contact</a></li>\n<li><a href="/useful-info/about-espc">About ESPC</a></li>\n<li><a href="/espc-policies">Terms &amp; Cookies</a></li>\n<li><a href="/advertise-your-business">Advertise</a></li>\n<li><a href="/useful-info/espc-jobs">Jobs</a></li>\n<li><a class="icon-twitter-squared" href="https://twitter.com/espc" target="_blank"><span class="away">Twitter</span></a></li>\n<li><a class="icon-facebook-squared" href="https://www.facebook.com/espc.property" target="_blank"><span class="away">Facebook</span></a></li>\n<li><a class="icon-instagram" href="https://www.instagram.com/espc.property/" target="_blank"><span class="away">Instagram</span></a></li>\n</ul>\n<p class="copyright col full_width clearfix">\n<span>ESPC (UK) Ltd is a company registered under the Companies Acts in Scotland (Registered Number SC203585)</span>\n<br/>\n<span>\xa9 2020 ESPC (UK) Ltd. All rights reserved.</span>\n<!-- Single line addresses on small devices -->\n<div class="col small_12 medium_hide large_hide">\n<span class="office-name">Head office: </span>ESPC, 90a George Street, Edinburgh, EH2 3DF\r\n                </div>\n<div class="col small_hide medium_hide large_hide">\n<span class="office-name">ESPC Property Information Centre: </span>107 George Street, Edinburgh, EH2 3ES\r\n                </div>\n<!-- Multi-line addresses on medium & large devices -->\n<div class="col small_hide medium_6 large_6">\n<span class="office-name office-name-multiline">Head office:</span>\r\n                    ESPC<br/>\r\n                    90a George Street<br/>\r\n                    Edinburgh<br/>\r\n                    EH2 3DF<br/>\n</div>\n<div class="col small_hide medium_6 large_6">\n<span class="office-name office-name-multiline">ESPC Property Information Centre:</span>\r\n                    107 George Street<br/>\r\n                    Edinburgh<br/>\r\n                    EH2 3ES<br/>\n</div>\n</p>\n</div>\n</div>\n</footer>\n<script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js" type="text/javascript"></script>\n<script src="/resources/js/dist/site.js?v=4364bcee978ec7723a16cef626afc34c" type="text/javascript"></script>\n<script src="/resources/js/dist/react-app-libs.js?v=e8fccea537345598f704f ...
