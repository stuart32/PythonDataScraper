# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://espc.com/house-prices/edinburgh")
soup = BeautifulSoup(page.content, 'html.parser')

# %%
html = list(soup.children)[2]

# %%
list(html.children)[3]

# %%
soup.find_all(id='propertiesList')
# Out:
# []

# %%
list(results)
# Out:
# []

# %%
print(soup.find('initalProps'))
# Out:
# None
